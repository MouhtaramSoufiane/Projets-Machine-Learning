# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set() #will import Seaborn fonctionalities

import warnings #if you do not see warnings 
warnings.filterwarnings('ignore')

# %%
#loading data titanic
titanic_dataset=pd.read_csv("C:/Users/lenovo/PycharmProjects/TITANIC_ANALYSE_DATA/tested.csv" ,sep=',')
titanic_dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
type(titanic_dataset.loc[0])
print(titanic_dataset.iloc[0])
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
print(titanic_dataset.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#subset a columns age 
colmns_age=titanic_dataset.loc[:,['Age']]
colmns_age.head(n=1)
# Out:
#     Age
# 0  34.5

# %%
#display max columns
pd.options.display.max_columns=12

# %%
#show the first 5 rows
titanic_dataset.head(3)
# Out:
#    PassengerId  ...  Embarked
# 0          892  ...         Q
# 1          893  ...         S
# 2          894  ...         Q
#
# [3 rows x 12 columns]

# %%
#get more information about coulmns
titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic_dataset.describe()
# Out:
#        PassengerId  ...        Fare
# count   418.000000  ...  417.000000
# mean   1100.500000  ...   35.627188
# std     120.810458  ...   55.907576
# min     892.000000  ...    0.000000
# 25%     996.250000  ...    7.895800
# 50%    1100.500000  ...   14.454200
# 75%    1204.750000  ...   31.500000
# max    1309.000000  ...  512.329200
#
# [8 rows x 7 columns]

# %%
# Visualize the data (Series Age and Fare)
plt.plot(titanic_dataset["Age"],titanic_dataset["Fare"], '+')
plt.show()

# %%
titanic_dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#nettoyer notre dataset
titanic_dataset.drop(columns=['Name','Sex','Embarked'])
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch              Ticket  \
# 0            892         0       3  34.5      0      0              330911
# 1            893         1       3  47.0      1      0              363272
# 2            894         0       2  62.0      0      0              240276
# 3            895         0       3  27.0      0      0              315154
# 4            896         1       3  22.0      1      1             3101298
# ..           ...       ...     ...   ...    ...    ...                 ...
# 413         1305         0       3   NaN      0      0           A.5. 3236
# 414         1306         1       1  39.0      0      0            PC 17758
# 415         1307         0       3  38.5      0      0  SOTON/O.Q. 3101262
# 416         1308         0       3   NaN      0      0              359309
# 417         1309         0       3   NaN      1      1                2668
#
#          Fare Cabin
# 0      7.8292   NaN
# 1      7.0000   NaN
# ...

# %%
#shape data
titanic_dataset.shape
# Out:
# (418, 12)

# %%
#slicing data
data_p=titanic_dataset.loc[titanic_dataset['Survived']==1]
data_n=titanic_dataset.loc[titanic_dataset['Survived']==0]
data_n
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
#print old columns
titanic_dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#pip install pyjanitor
#the above library we can used if we do not have a unique format name s columns
import janitor
titanic_dataset.clean_names()
#cleanning names coulmns
print(titanic_dataset.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_dataset.describe()
# Out:
#        PassengerId  ...        Fare
# count   418.000000  ...  417.000000
# mean   1100.500000  ...   35.627188
# std     120.810458  ...   55.907576
# min     892.000000  ...    0.000000
# 25%     996.250000  ...    7.895800
# 50%    1100.500000  ...   14.454200
# 75%    1204.750000  ...   31.500000
# max    1309.000000  ...  512.329200
#
# [8 rows x 7 columns]

# %%
titanic_dataset.describe().T
# Out:
#              count  ...        max
# PassengerId  418.0  ...  1309.0000
# Survived     418.0  ...     1.0000
# Pclass       418.0  ...     3.0000
# Age          332.0  ...    76.0000
# SibSp        418.0  ...     8.0000
# Parch        418.0  ...     9.0000
# Fare         417.0  ...   512.3292
#
# [7 rows x 8 columns]

# %%
#include categorical data in describe method
titanic_dataset.describe(include=['object'])
# Out:
#                     Name  ... Embarked
# count                418  ...      418
# unique               418  ...        3
# top     Kelly, Mr. James  ...        S
# freq                   1  ...      270
#
# [4 rows x 5 columns]

# %%
#value_counts() method used when have a features (Categorical (Object) and Booleen (binary)) for look a distrubition
titanic_dataset['Embarked'].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
titanic_dataset['Embarked'].value_counts(normalize=True)
# Out:
# S    0.645933
# C    0.244019
# Q    0.110048
# Name: Embarked, dtype: float64

# %%
#we used that section for now if we have target variable : imbalanced or not
#in this example we have impanced data so we must balanced : there are many ways to banalced (Oversampling ,UnderSampling,Smote)
(titanic_dataset['Embarked'].value_counts().plot(
   kind='bar',
   figsize=(8,6),
   title='Distrubition of target Variable : Embarked'
)
);
plt.show()

# %%
Emabrked_S=titanic_dataset[titanic_dataset['Embarked']=='S']
Emabrked_C=titanic_dataset[titanic_dataset['Embarked']=='C']
Embarked_Q=titanic_dataset[titanic_dataset['Embarked']=='Q']
Emabrked_S['Age']
# Out:
# 1      47.0
# 3      27.0
# 4      22.0
# 5      14.0
# 7      26.0
#        ...
# 409     3.0
# 412    28.0
# 413     NaN
# 415    38.5
# 416     NaN
# Name: Age, Length: 270, dtype: float64

# %%
# create the entire figure where our subplots will go
fig=plt.figure()# tell the figure how the subplots should be laid out
# in the example, we will have
# 2 row of plots, and each row will have 2 plots
# subplot has 2 rows and 2 columns, plot location 1
axes1 = fig.add_subplot(2, 2, 1)
axes1.plot(Emabrked_S['Age'],Emabrked_S['Fare'],'o')

# subplot has 2 rows and 2 columns, plot location 2
axes2 = fig.add_subplot(2, 2, 2)
axes2.plot(Emabrked_C['Age'],Emabrked_C['Fare'],'o')


# subplot has 2 rows and 2 columns, plot location 3
axes3 = fig.add_subplot(2, 2, 3)
axes3.plot(Embarked_Q['Age'],Embarked_Q['Fare'],'o')

# %%
print(Emabrked_S)
print(Emabrked_C)
print(Embarked_Q)
# Out:
#      PassengerId  ...  Embarked
# 1            893  ...         S
# 3            895  ...         S
# 4            896  ...         S
# 5            897  ...         S
# 7            899  ...         S
# ..           ...  ...       ...
# 409         1301  ...         S
# 412         1304  ...         S
# 413         1305  ...         S
# 415         1307  ...         S
# 416         1308  ...         S
#
# [270 rows x 12 columns]
#      PassengerId  ...  Embarked
# 8            900  ...         C
# 15           907  ...         C
# 17           909  ...         C
# 19           911  ...         C
# 20           912  ...         C
# ..           ...  ...       ...
# 404         1296  ...         C
# 405         1297  ...         C
# 407         1299  ...         C
# 414         1306  ...         C
# 417         1309  ...         C
#
# [102 rows x 12 columns]
#      PassengerId  ...  Embarked
# 0            892  ...         Q
# 2            894  ...         Q
# ...

# %%
#Correlation between variables data

confusion_matrix=titanic_dataset.corr(method='spearman')
confusion_matrix
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.034246 -0.018897 -0.010179  0.050692
# Survived       -0.023245  1.000000 -0.101313 -0.020605  0.150420  0.225146
# Pclass         -0.034246 -0.101313  1.000000 -0.471535 -0.118701 -0.043345
# Age            -0.018897 -0.020605 -0.471535  1.000000 -0.015126 -0.130408
# SibSp          -0.010179  0.150420 -0.118701 -0.015126  1.000000  0.412449
# Parch           0.050692  0.225146 -0.043345 -0.130408  0.412449  1.000000
# Fare            0.020174  0.204978 -0.753744  0.315220  0.441343  0.378496
#
#                  Fare
# PassengerId  0.020174
# Survived     0.204978
# Pclass      -0.753744
# Age          0.315220
# SibSp        0.441343
# Parch        0.378496
# Fare         1.000000

# %%
plt.rcParams['figure.figsize']=20,10
sns.heatmap(titanic_dataset.corr())
# Out:
# <AxesSubplot:>

# %%
# !pip install pandas-profiling
# Out:
# ...
#      ------------------------------------ 324.4/324.4 kB 913.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 345.9/345.9 kB 1.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 102.7/102.7 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 296.5/296.5 kB 2.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 2.2/2.2 MB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 663.5/663.5 kB 2.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.7/4.7 MB 2.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=da4ffb8f7d68e567a586dc0203225e15083e18ceacf96dfca02db8acb111143c
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# ...

# %%
import pandas_profiling
from pandas_profiling import profile_report
#profiling data

titanic_dataset.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-04-03 11:30:31.846322&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
